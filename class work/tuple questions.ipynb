# %%
# 1. Write a Python program to create a tuple.
a=(1,2,3,4) 
print(a)
# Out:
# (1, 2, 3, 4)

# %%
#2.Write a Python program to create a tuple with different data types.
a=(1,'a',True,1+2j)
print(a)
b=([1,2],[3,4],(1,2),{1:'a'},{1,2},frozenset({1,2}))
print(b)
# Out:
# (1, 'a', True, (1+2j))
# ([1, 2], [3, 4], (1, 2), {1: 'a'}, {1, 2}, frozenset({1, 2}))

# %%
#3. Write a Python program to create a tuple of numbers and print one item.
a=(1,2,3,4) 
print(a[0])
# Out:
# 1

# %%
# 4. Write a Python program to add an item to a tuple.
a=(1,2,3,4) 
a+=(5,)
print(a)
# Out:
# (1, 2, 3, 4, 5)

# %%
#6.Write a Python program to convert a tuple to a string
a=('a',2,3,4) 
s=''
for i in a:
    s+=str(i)
print(s)
# Out:
# a234

# %%
# 7. Write a Python program to get the 4 th  element from the last element of a tuple.
a=(1,2,3,4,5,6,7,8,9) 
print(a[-4])
# Out:
# 6

# %%
# 8.Write a Python program to create the colon of tuple
a=(1,2,3,4,5,6,7,8,9)
print(a[1:5])
# Out:
# (2, 3, 4, 5)

# %%
# 9. Write a Python program to find repeated items in a tuple.
a=(1,2,4,2,5,2)
for i in a:
    if a.count(i)>1:
       print(i)
       break
# Out:
# 2

# %%
# 10.Write a Python program to check whether an element exists within a tuple.
def checkel(t,e=3):
    if e in t:
        return True
    else:
        return False
t=(1,2,4,2,5,2)
checkel(t)
# Out:
# False

# %%
# 11. Write a Python program to convert a list to a tuple.
t=[1,2,4,2,5,2]
print(tuple(t))
# Out:
# (1, 2, 4, 2, 5, 2)

# %%
# 12. Write a Python program to remove an item from a tuple.
t=(1,2,4,2,5,2)
r=()
item=int(input())
for i in t:
    if i!=item:
        r+=(i,)
print(r)
# Out:
#  2
# (1, 4, 5)

# %%
# 13. Write a Python program to slice a tuple.
t=(1,2,4,2,5,2)
print(t[1:2])
# Out:
# (2,)

# %%
# 14. Write a Python program to find the index of an item in a tuple.
t=(1,2,4,2,5,2)
item=int(input())
for i in range(len(t)):
    if t[i]==item:
        print(i)
# Out:
#  5
# 4

# %%
# 15. Write a Python program to find the length of a tuple
a=(1,2,3,4)
print(len(a))
# Out:
# 4
