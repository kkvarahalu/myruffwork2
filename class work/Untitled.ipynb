# %%
import work2
dir(work2)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'l1',
#  'l2',
#  'merl',
#  'sor',
#  'sore']

# %%
import work2
l1=[1, 2, 9]
l2=[3, 1, 4, 2, 9]
l1=work2.sor(l1)
l2=work2.sore(l2)
work2.merl(l1, l2)
# Out:
# [1, 1, 2, 2, 3, 4, 9, 9]
