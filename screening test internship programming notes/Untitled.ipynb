# %%
n=int(input())
if n&1==0:
    print('even')
else:
    print('odd')
# Out:
#  11
# odd

# %%
n=int(input())
c=0
while n>0:
    if n&1!=0:
        c+=1
    n=n>>1
print(c)
# Out:
#  23
# 4

# %%
#
n=12
k=2
c=0
# Out:
# True

# %%
def swap(a,b):
    a=a^b
    b=a^b
    a=a^b
    return a,b
print(swap(5,9))
# Out:
# (9, 5)

# %%
a=5
b=9
a=a^b
b=a^b
a=a^b
print(a,b)
# Out:
# 9 5

# %%
n=[2,3,5,4,5,3,2]
for i in n:
    if

# %%
n=int(input())

# %%
# Bitwise Practice Questions

# 1. Check if a number is even or odd using bitwise

# Input: n = 11

# Output: Odd

# 2. Count set bits in a number

# Input: n=23(10111)

# Output: 4

# 3. Check if k-th bit (from right) is set

# Input: n = 12 (1100), k = 2

# Output: True

# 4. Swap two numbers without using a temporary variable (use XOR)

# Input: a = 5, b = 9

# Output: a = 9, b = 5

# 5.Find the only number that appears once (others appear twice)
# Input: [2, 3, 5, 4, 5, 3, 2]
# Output: 4

# 6. Check if a number is a power of 2 ? 

# Input: n=16
# Output: True
# Input: n=18
# Output: False

Find XOR of all numbers from 1 to n

Input: n = 7

Output: 0
(since 1^2^3^4^5^6^7 = 0)
