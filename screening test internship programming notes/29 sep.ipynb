# %%
#two refferences are there one is self it is access in inside and another is object that is access to the outside

# %%
class sample:
    def __init__(self,name,age):
        self.name=name
        self.age=age
    def display(self):
        print(self.name)
        print(self.age)
obj=sample('kkv',23)
obj.display()
# Out:
# kkv
# 23

# %%
obj.city='hyd'

# %%
obj.name
# Out:
# 'kkv'

# %%
obj.age
# Out:
# 23

# %%
obj.city
# Out:
# 'hyd'

# %%
class sample:
    def __init__(self,name,age):
        self.name=name
        self.age=age
    def display(self):
        print(obj.name,obj.age)
        obj.gender='male'
        print(obj.gender)

# %%
obj=sample('kkv',23)

# %%
obj.display()
# Out:
# kkv 23
# male

# %%
obj.gender
# Out:
# 'male'

# %%
# can't be acesess inside because not using self refferense so get error
class sample:
    def __init__(self,name,age):
        obj.name=name
        obj.age=age
    def display(self):
        print(obj.name,obj.age)
        obj.gender="male"
        print(obj.gender)

# %%
obj=sample('kkv',23)

# %%
obj.display()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 obj.display()
#
# Cell In[11], line 7, in sample.display(self)
#       6 def display(self):
# ----> 7     print(obj.name,obj.age)
#       8     obj.gender="male"
#       9     print(obj.gender)
#
# AttributeError: 'sample' object has no attribute 'name'

# %%
class sample:
    def __init__(self,name,age):
        self.name=name
        self.age=age
    def display(self):
        print(self.name,self.age)

# %%
p1=sample('abc',23)

# %%
p2=p1

# %%
id(p1)

# %%
id(p2)

# %%
p2.display()

# %%
class sample:
    def __init__(self):
        self.name='abc'
        self.age=234
def display(self):
    print(obj.name)
    print(obj.age)

# %%
obj=sample()

# %%
display(obj)

# %%
class sample:
    def __init__(self):
        self.name="abc"
        self.age=234
def display(r):
    print(r.name)
    print(r.age)

# %%
r=sample()

# %%
display(r)

# %%
class sample:
    def __init__(self,name,roll,city):
        self.name=name
        self.roll=roll
        self.city=city
    def display(self):
        display1(self)
def display1(obj):
    print(obj.name,obj.roll,obj.city)

# %%
obj=sample('kkv',23,'vizag')

# %%
obj.display()

# %%
class base:
    def display(self):
        print('hello')

# %%
s=base()

# %%
s.display()

# %%
class base:
    def display(self):
        print('hellow')

# %%
class derived(base):
    def display1(self):
        print('accessing base class data')

# %%
obj=derived()
obj.display1()

# %%
obj.display()

# %%
class Stack:
    def __init__(self):
        self.stack=[]
    def push(self,ele):
        self.stack.append(ele)
        return self.stack
    def pop(self):
        if self.isEmpty():
            return 'stack is empty'
        else:
            return self.stack.pop()
    def peek(self):
        if self.isEmpty():
            return 'stack is empty'
        return self.stack[-1]
    def isEmpty(self):
        return len(self.stack)==0
    def size(self):
        return len(self.stack)
myres=Stack()
myres.push(5)
myres.push(6)
myres.push(7)
myres.pop()
myres.peek()
myres.isEmpty()
myres.size()
# Out:
# 2

# %%
# Push: Adds a new element on the stack.
# Pop: Removes and returns the top element from the stack.
# Peek: Returns the top (last) element on the stack.
# isEmpty: Checks if the stack is empty.
# Size: Finds the number of elements in the stack.

# %%
class Stack:
  def __init__(self):
    self.stack = []

  def push(self, element):
    self.stack.append(element)

  def pop(self):
    if self.isEmpty():
      return "Stack is empty"
    return self.stack.pop()

  def peek(self):
    if self.isEmpty():
      return "Stack is empty"
    return self.stack[-1]

  def isEmpty(self):
    return len(self.stack) == 0

  def size(self):
    return len(self.stack)

# Create a stack
myStack = Stack()

myStack.push('A')
myStack.push('B')
myStack.push('C')

print("Stack: ", myStack.stack)
print("Pop: ", myStack.pop())
print("Stack after Pop: ", myStack.stack)
print("Peek: ", myStack.peek())
print("isEmpty: ", myStack.isEmpty())
print("Size: ", myStack.size())
# Out:
# Stack:  ['A', 'B', 'C']
# Pop:  C
# Stack after Pop:  ['A', 'B']
# Peek:  B
# isEmpty:  False
# Size:  2

# %%
class stack:
    def __init__(self):
        self.stack=[]
    def push(self,element):
        self.stack.append(element)
        return self.stack
    def pop(self):
        self.stack.pop()
        return self.stack
class browser_history(stack):
    print('hello')

# %%
bh= browser_history()

# %%
bh.push('www.google.com')

# %%
bh.push('www.abc.com')

# %%
bh.pop()

# %%
class person:
    def __init__(self,name,age):
        self.name=name
        self.age=age
class student(person):
    def __init__(self,name,age,roll,grades):
        super().__init__(name,age)
        self.roll=roll
        self.grades=grades
class graduate_student(student):
    def __init__(self,name,age,roll,grades,degree):
        super().__init__(name,age,roll,grades)
        self.degree=degree
    def display(self):
        print(self.name)
        print(self.age)
        print(self.roll)
        print(self.grades)
        print(self.degree)

# %%
gs=graduate_student("mayur",29,101,"A","Btech")

# %%
gs.display()
