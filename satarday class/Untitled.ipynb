# %%
def doc(d1,d2):
    list1=d1.lower().split()
    list2=d2.lower().split()
    dict1={}
    dict2={}
    for word in d1:
        if word in dict1:
            dict1[word]+=1
        else:
            dict1[word]=1
    
    for word in d2:
        if word in dict2:
            dict2[word]+=1
        else:
            dict2[word]=1
    return dict1,dict2
d1="i love programming"
d2="I Love Programming"
print(doc(d1,d2))
# Out:
# ({'i': 2, ' ': 2, 'l': 1, 'o': 2, 'v': 1, 'e': 1, 'p': 1, 'r': 2, 'g': 2, 'a': 1, 'm': 2, 'n': 1}, {'I': 1, ' ': 2, 'L': 1, 'o': 2, 'v': 1, 'e': 1, 'P': 1, 'r': 2, 'g': 2, 'a': 1, 'm': 2, 'i': 1, 'n': 1})
