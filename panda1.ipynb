# %%
def sum(num):
    if num==0:
        return num
    return num+sum(num-1)
print(sum(2))
# Out:
# 3

# %%
import pandas as pd

# %%
data={'num':[8,8,3,3,4,5,6]}

# %%
data
# Out:
# {'num': [8, 8, 3, 3, 4, 5, 6]}

# %%
a=pd.Series(data)
print(a)
# Out:
# num    [8, 8, 3, 3, 4, 5, 6]
# dtype: object

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#    num
# 0    8
# 1    8
# 2    3
# 3    3
# 4    4
# 5    5
# 6    6

# %%
df['num'].max()
# Out:
# 8

# %%
count=df['num'].value_counts()

# %%
count
# Out:
# num
# 8    2
# 3    2
# 4    1
# 5    1
# 6    1
# Name: count, dtype: int64

# %%
 unique_nums=count[count == 1].index

# %%
unique_nums
# Out:
# Index([4, 5, 6], dtype='int64', name='num')

# %%
['unique_nums'].max()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 ['unique_nums'].max()
#
# AttributeError: 'list' object has no attribute 'max'

# %%
import pandas as pd

# %%
friuts={"apple":121,"orrenge":13,"banana":12}

# %%
a=pd.Series(friuts)

# %%
a
# Out:
# apple      121
# orrenge     13
# banana      12
# dtype: int64

# %%
data=({"name":"athars","age":22,"city":"odisa"},
{"name":"athars","age":22,"city":"odisa"})

# %%
a=pd.DataFrame(data)

# %%
a
# Out:
#      name  age   city
# 0  athars   22  odisa
# 1  athars   22  odisa

# %%
s=pd.Series([2,3,4,5,6,7])

# %%
s
# Out:
# 0    2
# 1    3
# 2    4
# 3    5
# 4    6
# 5    7
# dtype: int64

# %%
s1=pd.Series([1,2,3,4,5,6],index=['a','b','c','d','e','e'])

# %%
s1
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# e    6
# dtype: int64

# %%
fruits_dict={"orange":12,"apple":34,"banana":12}

# %%
fruits=pd.Series(fruits_dict)

# %%
fruits
# Out:
# orange    12
# apple     34
# banana    12
# dtype: int64

# %%
weather_data={"data":['1/1/2025','1/02/2025','1/03/2025','1/04/2025','1/05/2025'],
              "city":["mumbai","pune","delhi","hyderabad","chennai"],
              "temparature":[27,28,39,35,50],
              "windspeed":[4,5,6,7,8],
              "event":["sunny","cloudy","rainy","cloudy","sunny"]}

# %%
weather_data
# Out:
# {'data': ['1/1/2025', '1/02/2025', '1/03/2025', '1/04/2025', '1/05/2025'],
#  'city': ['mumbai', 'pune', 'delhi', 'hyderabad', 'chennai'],
#  'temparature': [27, 28, 39, 35, 50],
#  'windspeed': [4, 5, 6, 7, 8],
#  'event': ['sunny', 'cloudy', 'rainy', 'cloudy', 'sunny']}

# %%
d=pd.DataFrame(weather_data)

# %%
d
# Out:
#         data       city  temparature  windspeed   event
# 0   1/1/2025     mumbai           27          4   sunny
# 1  1/02/2025       pune           28          5  cloudy
# 2  1/03/2025      delhi           39          6   rainy
# 3  1/04/2025  hyderabad           35          7  cloudy
# 4  1/05/2025    chennai           50          8   sunny

# %%
df=pd.DataFrame(data,columns=["date","city","temp","windspeed","event"])

# %%
df
# Out:
#    date   city  temp  windspeed  event
# 0   NaN  odisa   NaN        NaN    NaN
# 1   NaN  odisa   NaN        NaN    NaN

# %%
data3=[{"name":"mayur","age":23,"city":"mumbai"},
     {"name":"mayur","age":23,"city":"mumbai"},
     {"name":"mayur","age":23,"city":"mumbai"},
     {"name":"mayur","age":23,"city":"mumbai"}]

# %%
data3
# Out:
# [{'name': 'mayur', 'age': 23, 'city': 'mumbai'},
#  {'name': 'mayur', 'age': 23, 'city': 'mumbai'},
#  {'name': 'mayur', 'age': 23, 'city': 'mumbai'},
#  {'name': 'mayur', 'age': 23, 'city': 'mumbai'}]

# %%
df4=pd.DataFrame(data3)

# %%
df4
# Out:
#     name  age    city
# 0  mayur   23  mumbai
# 1  mayur   23  mumbai
# 2  mayur   23  mumbai
# 3  mayur   23  mumbai

# %%
import numpy as np

# %%
data5=np.array([["mayur",29,"mumbai"],
                ["pqr",30,"pune"],
                ["xyz",31,"nagpur"],
                ["abc",32,"hyd"]])

# %%
data5
# Out:
# array([['mayur', '29', 'mumbai'],
#        ['pqr', '30', 'pune'],
#        ['xyz', '31', 'nagpur'],
#        ['abc', '32', 'hyd']], dtype='<U11')

# %%
df6=pd.DataFrame(data5,columns=["name","age","city"])

# %%
df6
# Out:
#     name age    city
# 0  mayur  29  mumbai
# 1    pqr  30    pune
# 2    xyz  31  nagpur
# 3    abc  32     hyd

# %%
import pandas as pd
a = pd.read_csv('matches.csv')

# %%
a
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
s1=pd.Series([1,2,3,4,5],index=["a","b","c","d","e"])

# %%
s1
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
s1.values
# Out:
# array([1, 2, 3, 4, 5], dtype=int64)

# %%
s1.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
#loading the dataset into dataframe
df=pd.read_csv("matches.csv")

# %%
df
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
df.ndim
# Out:
# 2

# %%
df.shape
# Out:
# (1095, 20)

# %%
df.shape[0]
# Out:
# 1095

# %%
df.shape[1]
# Out:
# 20

# %%
df
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
#getting first five rows
df.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
df.head(2)
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
#
#                    team2                  toss_winner toss_decision  \
# 0  Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1    Chennai Super Kings          Chennai Super Kings           bat
#
#                   winner result  result_margin  target_runs  target_overs  \
# 0  Kolkata Knight Riders   runs          140.0        223.0          20.0
# 1    Chennai Super Kings   runs           33.0        241.0          20.0
#
#   super_over method    umpire1      umpire2
# 0          N    NaN  Asad Rauf  RE Koertzen
# ...

# %%
df.tail()
# Out:
#            id season       city        date   match_type  player_of_match  \
# 1090  1426307   2024  Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309   2024  Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310   2024  Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311   2024    Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312   2024    Chennai  2024-05-26        Final         MA Starc
#
#                                                   venue  \
# 1090  Rajiv Gandhi International Stadium, Uppal, Hyd...
# 1091                   Narendra Modi Stadium, Ahmedabad
# 1092                   Narendra Modi Stadium, Ahmedabad
# 1093           MA Chidambaram Stadium, Chepauk, Chennai
# 1094           MA Chidambaram Stadium, Chepauk, Chennai
#
#                             team1                  team2          toss_winner  \
# 1090                 Punjab Kings    Sunrisers Hyderabad         Punjab Kings
# ...

# %%
df.tail(2)
# Out:
#            id season     city        date   match_type player_of_match  \
# 1093  1426311   2024  Chennai  2024-05-24  Qualifier 2   Shahbaz Ahmed
# 1094  1426312   2024  Chennai  2024-05-26        Final        MA Starc
#
#                                          venue                team1  \
# 1093  MA Chidambaram Stadium, Chepauk, Chennai  Sunrisers Hyderabad
# 1094  MA Chidambaram Stadium, Chepauk, Chennai  Sunrisers Hyderabad
#
#                       team2          toss_winner toss_decision  \
# 1093       Rajasthan Royals     Rajasthan Royals         field
# 1094  Kolkata Knight Riders  Sunrisers Hyderabad           bat
#
#                      winner   result  result_margin  target_runs  \
# 1093    Sunrisers Hyderabad     runs           36.0        176.0
# 1094  Kolkata Knight Riders  wickets            8.0        114.0
#
#       target_overs super_over method        umpire1      umpire2
# 1093          20.0          N    NaN    Nitin Menon    VK Sharma
# ...

# %%
df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1095 non-null   int64
#  1   season           1095 non-null   object
#  2   city             1044 non-null   object
#  3   date             1095 non-null   object
#  4   match_type       1095 non-null   object
#  5   player_of_match  1090 non-null   object
#  6   venue            1095 non-null   object
#  7   team1            1095 non-null   object
#  8   team2            1095 non-null   object
#  9   toss_winner      1095 non-null   object
#  10  toss_decision    1095 non-null   object
#  11  winner           1090 non-null   object
#  12  result           1095 non-null   object
#  13  result_margin    1076 non-null   float64
#  14  target_runs      1092 non-null   float64
#  15  target_overs     1092 non-null   float64
# ...

# %%
df.describe()
# Out:
#                  id  result_margin  target_runs  target_overs
# count  1.095000e+03    1076.000000  1092.000000   1092.000000
# mean   9.048283e+05      17.259294   165.684066     19.759341
# std    3.677402e+05      21.787444    33.427048      1.581108
# min    3.359820e+05       1.000000    43.000000      5.000000
# 25%    5.483315e+05       6.000000   146.000000     20.000000
# 50%    9.809610e+05       8.000000   166.000000     20.000000
# 75%    1.254062e+06      20.000000   187.000000     20.000000
# max    1.426312e+06     146.000000   288.000000     20.000000

# %%
df["city"]
# Out:
# 0        Bangalore
# 1       Chandigarh
# 2            Delhi
# 3           Mumbai
# 4          Kolkata
#            ...
# 1090     Hyderabad
# 1091     Ahmedabad
# 1092     Ahmedabad
# 1093       Chennai
# 1094       Chennai
# Name: city, Length: 1095, dtype: object

# %%
type(df["city"])
# Out:
# pandas.core.series.Series

# %%
df.head(2)
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
#
#                    team2                  toss_winner toss_decision  \
# 0  Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1    Chennai Super Kings          Chennai Super Kings           bat
#
#                   winner result  result_margin  target_runs  target_overs  \
# 0  Kolkata Knight Riders   runs          140.0        223.0          20.0
# 1    Chennai Super Kings   runs           33.0        241.0          20.0
#
#   super_over method    umpire1      umpire2
# 0          N    NaN  Asad Rauf  RE Koertzen
# ...

# %%
s=df[["team1","team2","winner"]]

# %%
s
# Out:
#                             team1                        team2  \
# 0     Royal Challengers Bangalore        Kolkata Knight Riders
# 1                 Kings XI Punjab          Chennai Super Kings
# 2                Delhi Daredevils             Rajasthan Royals
# 3                  Mumbai Indians  Royal Challengers Bangalore
# 4           Kolkata Knight Riders              Deccan Chargers
# ...                           ...                          ...
# 1090                 Punjab Kings          Sunrisers Hyderabad
# 1091          Sunrisers Hyderabad        Kolkata Knight Riders
# 1092  Royal Challengers Bengaluru             Rajasthan Royals
# 1093          Sunrisers Hyderabad             Rajasthan Royals
# 1094          Sunrisers Hyderabad        Kolkata Knight Riders
#
#                            winner
# 0           Kolkata Knight Riders
# 1             Chennai Super Kings
# 2                Delhi Daredevils
# 3     Royal Challengers Bangalore
# ...

# %%
type(s)
# Out:
# pandas.core.frame.DataFrame

# %%
df.iloc[0]
# Out:
# id                                      335982
# season                                 2007/08
# city                                 Bangalore
# date                                2008-04-18
# match_type                              League
# player_of_match                    BB McCullum
# venue                    M Chinnaswamy Stadium
# team1              Royal Challengers Bangalore
# team2                    Kolkata Knight Riders
# toss_winner        Royal Challengers Bangalore
# toss_decision                            field
# winner                   Kolkata Knight Riders
# result                                    runs
# result_margin                            140.0
# target_runs                              223.0
# target_overs                              20.0
# super_over                                   N
# method                                     NaN
# umpire1                              Asad Rauf
# umpire2                            RE Koertzen
# ...

# %%
#fancy indexing
df.iloc[[0,1]]
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
#
#                    team2                  toss_winner toss_decision  \
# 0  Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1    Chennai Super Kings          Chennai Super Kings           bat
#
#                   winner result  result_margin  target_runs  target_overs  \
# 0  Kolkata Knight Riders   runs          140.0        223.0          20.0
# 1    Chennai Super Kings   runs           33.0        241.0          20.0
#
#   super_over method    umpire1      umpire2
# 0          N    NaN  Asad Rauf  RE Koertzen
# ...

# %%
df.iloc[2:10]
# Out:
#        id   season        city        date match_type player_of_match  \
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
# 5  335987  2007/08      Jaipur  2008-04-21     League       SR Watson
# 6  335988  2007/08   Hyderabad  2008-04-22     League        V Sehwag
# 7  335989  2007/08     Chennai  2008-04-23     League       ML Hayden
# 8  335990  2007/08   Hyderabad  2008-04-24     League       YK Pathan
# 9  335991  2007/08  Chandigarh  2008-04-25     League   KC Sangakkara
#
#                                         venue                  team1  \
# 2                            Feroz Shah Kotla       Delhi Daredevils
# 3                            Wankhede Stadium         Mumbai Indians
# 4                                Eden Gardens  Kolkata Knight Riders
# ...

# %%
df[1::2]
# Out:
#            id   season        city        date   match_type player_of_match  \
# 1      335983  2007/08  Chandigarh  2008-04-19       League      MEK Hussey
# 3      335985  2007/08      Mumbai  2008-04-20       League      MV Boucher
# 5      335987  2007/08      Jaipur  2008-04-21       League       SR Watson
# 7      335989  2007/08     Chennai  2008-04-23       League       ML Hayden
# 9      335991  2007/08  Chandigarh  2008-04-25       League   KC Sangakkara
# ...       ...      ...         ...         ...          ...             ...
# 1085  1426300     2024   Bengaluru  2024-05-12       League         C Green
# 1087  1426303     2024    Guwahati  2024-05-15       League       SM Curran
# 1089  1426306     2024   Bengaluru  2024-05-18       League    F du Plessis
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1        MA Starc
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2   Shahbaz Ahmed
#
# ...

# %%
df["city"]
# Out:
# 0        Bangalore
# 1       Chandigarh
# 2            Delhi
# 3           Mumbai
# 4          Kolkata
#            ...
# 1090     Hyderabad
# 1091     Ahmedabad
# 1092     Ahmedabad
# 1093       Chennai
# 1094       Chennai
# Name: city, Length: 1095, dtype: object

# %%
df["city"]=="Hyderbad"
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1090    False
# 1091    False
# 1092    False
# 1093    False
# 1094    False
# Name: city, Length: 1095, dtype: bool

# %%
df["city"]=="Hyderbad"
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1090    False
# 1091    False
# 1092    False
# 1093    False
# 1094    False
# Name: city, Length: 1095, dtype: bool

# %%
df[df["city"]=="Hyderabad"]
# Out:
#            id   season       city        date match_type  player_of_match  \
# 6      335988  2007/08  Hyderabad  2008-04-22     League         V Sehwag
# 8      335990  2007/08  Hyderabad  2008-04-24     League        YK Pathan
# 17     335999  2007/08  Hyderabad  2008-05-01     League         SE Marsh
# 31     336014  2007/08  Hyderabad  2008-05-11     League       SC Ganguly
# 40     336024  2007/08  Hyderabad  2008-05-18     League         DJ Bravo
# ...       ...      ...        ...         ...        ...              ...
# 1041  1422136     2024  Hyderabad  2024-04-05     League  Abhishek Sharma
# 1064  1426279     2024  Hyderabad  2024-04-25     League       RM Patidar
# 1073  1426288     2024  Hyderabad  2024-05-02     League          B Kumar
# 1080  1426295     2024  Hyderabad  2024-05-08     League          TM Head
# 1090  1426307     2024  Hyderabad  2024-05-19     League  Abhishek Sharma
#
#                                                   venue  \
# ...

# %%
df[df["city"]=="Mumbai"]
# Out:
#            id   season    city        date match_type player_of_match  \
# 3      335985  2007/08  Mumbai  2008-04-20     League      MV Boucher
# 12     335994  2007/08  Mumbai  2008-04-27     League    AC Gilchrist
# 22     336004  2007/08  Mumbai  2008-05-04     League      SM Pollock
# 26     336008  2007/08  Mumbai  2008-05-07     League         A Nehra
# 35     336018  2007/08  Mumbai  2008-05-14     League   ST Jayasuriya
# ...       ...      ...     ...         ...        ...             ...
# 1048  1426263     2024  Mumbai  2024-04-11     League       JJ Bumrah
# 1052  1426267     2024  Mumbai  2024-04-14     League     M Pathirana
# 1074  1426289     2024  Mumbai  2024-05-03     League         VR Iyer
# 1078  1426293     2024  Mumbai  2024-05-06     League        SA Yadav
# 1088  1426305     2024  Mumbai  2024-05-17     League        N Pooran
#
#                            venue                        team1  \
# 3               Wankhede Stadium               Mumbai Indians
# ...

# %%
df[df['date']>'2017-01--01']
# Out:
#            id season       city        date   match_type  player_of_match  \
# 577   1082591   2017  Hyderabad  2017-04-05       League     Yuvraj Singh
# 578   1082592   2017       Pune  2017-04-06       League        SPD Smith
# 579   1082593   2017     Rajkot  2017-04-07       League          CA Lynn
# 580   1082594   2017     Indore  2017-04-08       League       GJ Maxwell
# 581   1082595   2017  Bengaluru  2017-04-08       League        KM Jadhav
# ...       ...    ...        ...         ...          ...              ...
# 1090  1426307   2024  Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309   2024  Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310   2024  Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311   2024    Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312   2024    Chennai  2024-05-26        Final         MA Starc
#
#                                                   venue  \
# ...

# %%
#all the matches after 2017 which is played in mumbai
#how many matches played in mumbai
mask=df["city"]=="Mumbai"

# %%
df[mask].shape[0]
# Out:
# 173

# %%
df[mask].shape[0]
# Out:
# 173

# %%
def count_matches_city(df,city):
    mask=df["city"]==city
    return df[mask].shape[0]

# %%
count_matches_city(df,'Bangalore')
# Out:
# 65

# %%
import pandas as pd

# %%
df=pd.read_csv("weather_data.csv")

# %%
df
# Out:
#     Unnamed: 0       day     city  temperature  windspeed   event
# 0            0  1/1/2025  newyork           32          6   rainy
# 1            1  1/2/2025  newyork           36          7   sunny
# 2            2  1/3/2025  newyork           28         12    snow
# 3            3  1/4/2025  newyork           33          7   sunny
# 4            4  1/1/2025   mumbai           90          5   sunny
# 5            5  1/2/2025   mumbai           85         12     fog
# 6            6  1/3/2025   mumbai           87         15     fog
# 7            7  1/4/2025   mumbai           92          5   rainy
# 8            8  1/1/2025    paris           45         20   sunny
# 9            9  1/2/2025    paris           50         13  cloudy
# 10          10  1/3/2025    paris           54          8  cloudy
# 11          11  1/4/2025    paris           52         10  cloudy

# %%
#get the maximum temparature
df['temperature']
# Out:
# 0     32
# 1     36
# 2     28
# 3     33
# 4     90
# 5     85
# 6     87
# 7     92
# 8     45
# 9     50
# 10    54
# 11    52
# Name: temperature, dtype: int64

# %%
type(df['temperature'])
# Out:
# pandas.core.series.Series

# %%
df['temperature'].max()
# Out:
# 92

# %%
df['temperature'].min()
# Out:
# 28

# %%
df['day'][df['event']=="cloudy"]
# Out:
# 9     1/2/2025
# 10    1/3/2025
# 11    1/4/2025
# Name: day, dtype: object

# %%
df['day'][df['event']=="rainy"]
# Out:
# 0    1/1/2025
# 7    1/4/2025
# Name: day, dtype: object

# %%
df['day'][df['temperature']==df["temperature"].max()]
# Out:
# 7    1/4/2025
# Name: day, dtype: object

# %%
df['day'][df['temperature']==df["temperature"].min()]
# Out:
# 2    1/3/2025
# Name: day, dtype: object

# %%
df["windspeed"].mean()
# Out:
# 10.0

# %%
df['temperature'].describe()
# Out:
# count    12.000000
# mean     57.000000
# std      24.694497
# min      28.000000
# 25%      35.250000
# 50%      51.000000
# 75%      85.500000
# max      92.000000
# Name: temperature, dtype: float64

# %%
df[df.temperature==df["temperature"].max()]
# Out:
#    Unnamed: 0       day    city  temperature  windspeed  event
# 7           7  1/4/2025  mumbai           92          5  rainy

# %%
df[df.temperature==df["temperature"].min()]
# Out:
#    Unnamed: 0       day     city  temperature  windspeed event
# 2           2  1/3/2025  newyork           28         12  snow

# %%
#group by city
g=df.groupby('city')

# %%
g

# %%
for city,groupby in g:
    print(city)
    print(groupby)
# Out:
# mumbai
#    Unnamed: 0       day    city  temperature  windspeed  event
# 4           4  1/1/2025  mumbai           90          5  sunny
# 5           5  1/2/2025  mumbai           85         12    fog
# 6           6  1/3/2025  mumbai           87         15    fog
# 7           7  1/4/2025  mumbai           92          5  rainy
# newyork
#    Unnamed: 0       day     city  temperature  windspeed  event
# 0           0  1/1/2025  newyork           32          6  rainy
# 1           1  1/2/2025  newyork           36          7  sunny
# 2           2  1/3/2025  newyork           28         12   snow
# 3           3  1/4/2025  newyork           33          7  sunny
# paris
#     Unnamed: 0       day   city  temperature  windspeed   event
# 8            8  1/1/2025  paris           45         20   sunny
# 9            9  1/2/2025  paris           50         13  cloudy
# 10          10  1/3/2025  paris           54          8  cloudy
# ...

# %%
f=df.groupby('event')

# %%
for event,groupyby in f:
    print(event)
    print(groupby)
# Out:
# cloudy
#     Unnamed: 0       day   city  temperature  windspeed   event
# 8            8  1/1/2025  paris           45         20   sunny
# 9            9  1/2/2025  paris           50         13  cloudy
# 10          10  1/3/2025  paris           54          8  cloudy
# 11          11  1/4/2025  paris           52         10  cloudy
# fog
#     Unnamed: 0       day   city  temperature  windspeed   event
# 8            8  1/1/2025  paris           45         20   sunny
# 9            9  1/2/2025  paris           50         13  cloudy
# 10          10  1/3/2025  paris           54          8  cloudy
# 11          11  1/4/2025  paris           52         10  cloudy
# rainy
#     Unnamed: 0       day   city  temperature  windspeed   event
# 8            8  1/1/2025  paris           45         20   sunny
# 9            9  1/2/2025  paris           50         13  cloudy
# 10          10  1/3/2025  paris           54          8  cloudy
# ...

# %%
g.max()
# Out:
#          Unnamed: 0       day  temperature  windspeed  event
# city
# mumbai            7  1/4/2025           92         15  sunny
# newyork           3  1/4/2025           36         12  sunny
# paris            11  1/4/2025           54         20  sunny

# %%
g[['temperature','city']].max()
# Out:
#          temperature     city
# city
# mumbai            92   mumbai
# newyork           36  newyork
# paris             54    paris

# %%
g[['temperature','city']].min()
# Out:
#          temperature     city
# city
# mumbai            85   mumbai
# newyork           28  newyork
# paris             45    paris

# %%
g.windspeed.mean()
# Out:
# city
# mumbai      9.25
# newyork     8.00
# paris      12.75
# Name: windspeed, dtype: float64

# %%
df.rename(columns={'day':'date'})
# Out:
#     Unnamed: 0      date     city  temperature  windspeed   event
# 0            0  1/1/2025  newyork           32          6   rainy
# 1            1  1/2/2025  newyork           36          7   sunny
# 2            2  1/3/2025  newyork           28         12    snow
# 3            3  1/4/2025  newyork           33          7   sunny
# 4            4  1/1/2025   mumbai           90          5   sunny
# 5            5  1/2/2025   mumbai           85         12     fog
# 6            6  1/3/2025   mumbai           87         15     fog
# 7            7  1/4/2025   mumbai           92          5   rainy
# 8            8  1/1/2025    paris           45         20   sunny
# 9            9  1/2/2025    paris           50         13  cloudy
# 10          10  1/3/2025    paris           54          8  cloudy
# 11          11  1/4/2025    paris           52         10  cloudy

# %%
df.rename(columns={'day':'date'},inplace=True)

# %%
df
# Out:
#     Unnamed: 0      date     city  temperature  windspeed   event
# 0            0  1/1/2025  newyork           32          6   rainy
# 1            1  1/2/2025  newyork           36          7   sunny
# 2            2  1/3/2025  newyork           28         12    snow
# 3            3  1/4/2025  newyork           33          7   sunny
# 4            4  1/1/2025   mumbai           90          5   sunny
# 5            5  1/2/2025   mumbai           85         12     fog
# 6            6  1/3/2025   mumbai           87         15     fog
# 7            7  1/4/2025   mumbai           92          5   rainy
# 8            8  1/1/2025    paris           45         20   sunny
# 9            9  1/2/2025    paris           50         13  cloudy
# 10          10  1/3/2025    paris           54          8  cloudy
# 11          11  1/4/2025    paris           52         10  cloudy

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("weather_data.csv")

# %%
df
# Out:
#     Unnamed: 0       day     city  temperature  windspeed   event
# 0            0  1/1/2025  newyork           32          6   rainy
# 1            1  1/2/2025  newyork           36          7   sunny
# 2            2  1/3/2025  newyork           28         12    snow
# 3            3  1/4/2025  newyork           33          7   sunny
# 4            4  1/1/2025   mumbai           90          5   sunny
# 5            5  1/2/2025   mumbai           85         12     fog
# 6            6  1/3/2025   mumbai           87         15     fog
# 7            7  1/4/2025   mumbai           92          5   rainy
# 8            8  1/1/2025    paris           45         20   sunny
# 9            9  1/2/2025    paris           50         13  cloudy
# 10          10  1/3/2025    paris           54          8  cloudy
# 11          11  1/4/2025    paris           52         10  cloudy

# %%
df.shape
# Out:
# (12, 6)

# %%
df.ndim
# Out:
# 2

# %%
df.index[1:3]
# Out:
# RangeIndex(start=1, stop=3, step=1)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=12, step=1)

# %%
#df.values
df.values
# Out:
# array([[0, '1/1/2025', 'newyork', 32, 6, 'rainy'],
#        [1, '1/2/2025', 'newyork', 36, 7, 'sunny'],
#        [2, '1/3/2025', 'newyork', 28, 12, 'snow'],
#        [3, '1/4/2025', 'newyork', 33, 7, 'sunny'],
#        [4, '1/1/2025', 'mumbai', 90, 5, 'sunny'],
#        [5, '1/2/2025', 'mumbai', 85, 12, 'fog'],
#        [6, '1/3/2025', 'mumbai', 87, 15, 'fog'],
#        [7, '1/4/2025', 'mumbai', 92, 5, 'rainy'],
#        [8, '1/1/2025', 'paris', 45, 20, 'sunny'],
#        [9, '1/2/2025', 'paris', 50, 13, 'cloudy'],
#        [10, '1/3/2025', 'paris', 54, 8, 'cloudy'],
#        [11, '1/4/2025', 'paris', 52, 10, 'cloudy']], dtype=object)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'day', 'city', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# day            object
# city           object
# temperature     int64
# windspeed       int64
# event          object
# dtype: object

# %%
df.size
# Out:
# 72

# %%
df.T
# Out:
#                    0         1         2         3         4         5   \
# Unnamed: 0          0         1         2         3         4         5
# day          1/1/2025  1/2/2025  1/3/2025  1/4/2025  1/1/2025  1/2/2025
# city          newyork   newyork   newyork   newyork    mumbai    mumbai
# temperature        32        36        28        33        90        85
# windspeed           6         7        12         7         5        12
# event           rainy     sunny      snow     sunny     sunny       fog
#
#                    6         7         8         9         10        11
# Unnamed: 0          6         7         8         9        10        11
# day          1/3/2025  1/4/2025  1/1/2025  1/2/2025  1/3/2025  1/4/2025
# city           mumbai    mumbai     paris     paris     paris     paris
# temperature        87        92        45        50        54        52
# windspeed          15         5        20        13         8        10
# ...

# %%
df.memory_usage()
# Out:
# Index          132
# Unnamed: 0      96
# day             96
# city            96
# temperature     96
# windspeed       96
# event           96
# dtype: int64

# %%
df.head()
# Out:
#    Unnamed: 0       day     city  temperature  windspeed  event
# 0           0  1/1/2025  newyork           32          6  rainy
# 1           1  1/2/2025  newyork           36          7  sunny
# 2           2  1/3/2025  newyork           28         12   snow
# 3           3  1/4/2025  newyork           33          7  sunny
# 4           4  1/1/2025   mumbai           90          5  sunny

# %%
df.head(2)
# Out:
#    Unnamed: 0       day     city  temperature  windspeed  event
# 0           0  1/1/2025  newyork           32          6  rainy
# 1           1  1/2/2025  newyork           36          7  sunny

# %%
df.tail()
# Out:
#     Unnamed: 0       day    city  temperature  windspeed   event
# 7            7  1/4/2025  mumbai           92          5   rainy
# 8            8  1/1/2025   paris           45         20   sunny
# 9            9  1/2/2025   paris           50         13  cloudy
# 10          10  1/3/2025   paris           54          8  cloudy
# 11          11  1/4/2025   paris           52         10  cloudy

# %%
df.tail(2)
# Out:
#     Unnamed: 0       day   city  temperature  windspeed   event
# 10          10  1/3/2025  paris           54          8  cloudy
# 11          11  1/4/2025  paris           52         10  cloudy

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   12 non-null     int64
#  1   day          12 non-null     object
#  2   city         12 non-null     object
#  3   temperature  12 non-null     int64
#  4   windspeed    12 non-null     int64
#  5   event        12 non-null     object
# dtypes: int64(3), object(3)
# memory usage: 708.0+ bytes

# %%
df.describe()
# Out:
#        Unnamed: 0  temperature  windspeed
# count   12.000000    12.000000  12.000000
# mean     5.500000    57.000000  10.000000
# std      3.605551    24.694497   4.572646
# min      0.000000    28.000000   5.000000
# 25%      2.750000    35.250000   6.750000
# 50%      5.500000    51.000000   9.000000
# 75%      8.250000    85.500000  12.250000
# max     11.000000    92.000000  20.000000

# %%
df.isnull()
# Out:
#     Unnamed: 0    day   city  temperature  windspeed  event
# 0        False  False  False        False      False  False
# 1        False  False  False        False      False  False
# 2        False  False  False        False      False  False
# 3        False  False  False        False      False  False
# 4        False  False  False        False      False  False
# 5        False  False  False        False      False  False
# 6        False  False  False        False      False  False
# 7        False  False  False        False      False  False
# 8        False  False  False        False      False  False
# 9        False  False  False        False      False  False
# 10       False  False  False        False      False  False
# 11       False  False  False        False      False  False

# %%
df.isnull().sum()
# Out:
# Unnamed: 0     0
# day            0
# city           0
# temperature    0
# windspeed      0
# event          0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['temperature']
# Out:
# 0     32
# 1     36
# 2     28
# 3     33
# 4     90
# 5     85
# 6     87
# 7     92
# 8     45
# 9     50
# 10    54
# 11    52
# Name: temperature, dtype: int64

# %%
type(df["temperature"])
# Out:
# pandas.core.series.Series

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\ADMIN\\pandas file'

# %%
df[["city","temperature"]]
# Out:
#        city  temperature
# 0   newyork           32
# 1   newyork           36
# 2   newyork           28
# 3   newyork           33
# 4    mumbai           90
# 5    mumbai           85
# 6    mumbai           87
# 7    mumbai           92
# 8     paris           45
# 9     paris           50
# 10    paris           54
# 11    paris           52

# %%
df[['temperature']]
# Out:
#     temperature
# 0            32
# 1            36
# 2            28
# 3            33
# 4            90
# 5            85
# 6            87
# 7            92
# 8            45
# 9            50
# 10           54
# 11           52

# %%
#slicing
df.iloc[0]
# Out:
# Unnamed: 0            0
# day            1/1/2025
# city            newyork
# temperature          32
# windspeed             6
# event             rainy
# Name: 0, dtype: object

# %%
df.iloc[1:6]
# Out:
#    Unnamed: 0       day     city  temperature  windspeed  event
# 1           1  1/2/2025  newyork           36          7  sunny
# 2           2  1/3/2025  newyork           28         12   snow
# 3           3  1/4/2025  newyork           33          7  sunny
# 4           4  1/1/2025   mumbai           90          5  sunny
# 5           5  1/2/2025   mumbai           85         12    fog

# %%
df.iloc[[2,5]]
# Out:
#    Unnamed: 0       day     city  temperature  windspeed event
# 2           2  1/3/2025  newyork           28         12  snow
# 5           5  1/2/2025   mumbai           85         12   fog

# %%
#only slicing above table not original
df.iloc[2,5]
# Out:
# 'snow'

# %%
#Get the maximum temperature
df[['temperature']].max()
# Out:
# temperature    92
# dtype: int64

# %%
#Get the minimum temperature
df[['temperature']].min()
# Out:
# temperature    28
# dtype: int64

# %%
#which day its raining
df[['day']][df['event']=='rainy']
# Out:
#         day
# 0  1/1/2025
# 7  1/4/2025

# %%
#which day its cloudy
df[['day']][df['event']=='cloudy']
# Out:
#          day
# 9   1/2/2025
# 10  1/3/2025
# 11  1/4/2025

# %%
#get a day where the temperature is maximum
df['day'][df['temperature']==df['temperature'].max()]
# Out:
# 7    1/4/2025
# Name: day, dtype: object

# %%
#get a day where the minimum temperature 
df['day'][df['temperature']==df['temperature'].min()]
# Out:
# 2    1/3/2025
# Name: day, dtype: object

# %%
#what the average windspeed
df['windspeed'].mean()
# Out:
# 10.0

# %%
#describe the temperature
df['temperature'].describe()
# Out:
# count    12.000000
# mean     57.000000
# std      24.694497
# min      28.000000
# 25%      35.250000
# 50%      51.000000
# 75%      85.500000
# max      92.000000
# Name: temperature, dtype: float64

# %%
#select which row has maximum temperature
df[df.temperature==df['temperature'].max()]
# Out:
#    Unnamed: 0       day    city  temperature  windspeed  event
# 7           7  1/4/2025  mumbai           92          5  rainy

# %%
#select which row has minimum temperature
df[df.temperature==df['temperature'].min()]
# Out:
#    Unnamed: 0       day     city  temperature  windspeed event
# 2           2  1/3/2025  newyork           28         12  snow

# %%
#group by city
g=df.groupby('city')

# %%
g

# %%
df
# Out:
#     Unnamed: 0       day     city  temperature  windspeed   event
# 0            0  1/1/2025  newyork           32          6   rainy
# 1            1  1/2/2025  newyork           36          7   sunny
# 2            2  1/3/2025  newyork           28         12    snow
# 3            3  1/4/2025  newyork           33          7   sunny
# 4            4  1/1/2025   mumbai           90          5   sunny
# 5            5  1/2/2025   mumbai           85         12     fog
# 6            6  1/3/2025   mumbai           87         15     fog
# 7            7  1/4/2025   mumbai           92          5   rainy
# 8            8  1/1/2025    paris           45         20   sunny
# 9            9  1/2/2025    paris           50         13  cloudy
# 10          10  1/3/2025    paris           54          8  cloudy
# 11          11  1/4/2025    paris           52         10  cloudy

# %%
for city,group_df in g:
    print(city)
    print(group_df)
# Out:
# mumbai
#    Unnamed: 0       day    city  temperature  windspeed  event
# 4           4  1/1/2025  mumbai           90          5  sunny
# 5           5  1/2/2025  mumbai           85         12    fog
# 6           6  1/3/2025  mumbai           87         15    fog
# 7           7  1/4/2025  mumbai           92          5  rainy
# newyork
#    Unnamed: 0       day     city  temperature  windspeed  event
# 0           0  1/1/2025  newyork           32          6  rainy
# 1           1  1/2/2025  newyork           36          7  sunny
# 2           2  1/3/2025  newyork           28         12   snow
# 3           3  1/4/2025  newyork           33          7  sunny
# paris
#     Unnamed: 0       day   city  temperature  windspeed   event
# 8            8  1/1/2025  paris           45         20   sunny
# 9            9  1/2/2025  paris           50         13  cloudy
# 10          10  1/3/2025  paris           54          8  cloudy
# ...

# %%
#group by event
f=df.groupby('event')

# %%
f

# %%
for event,event_df in g:
    print(event)
    print(event_df)
# Out:
# mumbai
#    Unnamed: 0       day    city  temperature  windspeed  event
# 4           4  1/1/2025  mumbai           90          5  sunny
# 5           5  1/2/2025  mumbai           85         12    fog
# 6           6  1/3/2025  mumbai           87         15    fog
# 7           7  1/4/2025  mumbai           92          5  rainy
# newyork
#    Unnamed: 0       day     city  temperature  windspeed  event
# 0           0  1/1/2025  newyork           32          6  rainy
# 1           1  1/2/2025  newyork           36          7  sunny
# 2           2  1/3/2025  newyork           28         12   snow
# 3           3  1/4/2025  newyork           33          7  sunny
# paris
#     Unnamed: 0       day   city  temperature  windspeed   event
# 8            8  1/1/2025  paris           45         20   sunny
# 9            9  1/2/2025  paris           50         13  cloudy
# 10          10  1/3/2025  paris           54          8  cloudy
# ...

# %%
#find the maximum temperature in each cities
g.max()
# Out:
#          Unnamed: 0       day  temperature  windspeed  event
# city
# mumbai            7  1/4/2025           92         15  sunny
# newyork           3  1/4/2025           36         12  sunny
# paris            11  1/4/2025           54         20  sunny

# %%
#find the minimum temperature in each city
g.min()
# Out:
#          Unnamed: 0       day  temperature  windspeed   event
# city
# mumbai            4  1/1/2025           85          5     fog
# newyork           0  1/1/2025           28          6   rainy
# paris             8  1/1/2025           45          8  cloudy

# %%
#what is average temperature in each city
g.temperature.mean()
# Out:
# city
# mumbai     88.50
# newyork    32.25
# paris      50.25
# Name: temperature, dtype: float64

# %%
#what is average windspeed in each city
g.windspeed.mean()
# Out:
# city
# mumbai      9.25
# newyork     8.00
# paris      12.75
# Name: windspeed, dtype: float64

# %%
df
# Out:
#     Unnamed: 0       day     city  temperature  windspeed   event
# 0            0  1/1/2025  newyork           32          6   rainy
# 1            1  1/2/2025  newyork           36          7   sunny
# 2            2  1/3/2025  newyork           28         12    snow
# 3            3  1/4/2025  newyork           33          7   sunny
# 4            4  1/1/2025   mumbai           90          5   sunny
# 5            5  1/2/2025   mumbai           85         12     fog
# 6            6  1/3/2025   mumbai           87         15     fog
# 7            7  1/4/2025   mumbai           92          5   rainy
# 8            8  1/1/2025    paris           45         20   sunny
# 9            9  1/2/2025    paris           50         13  cloudy
# 10          10  1/3/2025    paris           54          8  cloudy
# 11          11  1/4/2025    paris           52         10  cloudy

# %%
df.rename(columns={"day":"date"})
# Out:
#     Unnamed: 0      date     city  temperature  windspeed   event
# 0            0  1/1/2025  newyork           32          6   rainy
# 1            1  1/2/2025  newyork           36          7   sunny
# 2            2  1/3/2025  newyork           28         12    snow
# 3            3  1/4/2025  newyork           33          7   sunny
# 4            4  1/1/2025   mumbai           90          5   sunny
# 5            5  1/2/2025   mumbai           85         12     fog
# 6            6  1/3/2025   mumbai           87         15     fog
# 7            7  1/4/2025   mumbai           92          5   rainy
# 8            8  1/1/2025    paris           45         20   sunny
# 9            9  1/2/2025    paris           50         13  cloudy
# 10          10  1/3/2025    paris           54          8  cloudy
# 11          11  1/4/2025    paris           52         10  cloudy

# %%
df
# Out:
#     Unnamed: 0       day     city  temperature  windspeed   event
# 0            0  1/1/2025  newyork           32          6   rainy
# 1            1  1/2/2025  newyork           36          7   sunny
# 2            2  1/3/2025  newyork           28         12    snow
# 3            3  1/4/2025  newyork           33          7   sunny
# 4            4  1/1/2025   mumbai           90          5   sunny
# 5            5  1/2/2025   mumbai           85         12     fog
# 6            6  1/3/2025   mumbai           87         15     fog
# 7            7  1/4/2025   mumbai           92          5   rainy
# 8            8  1/1/2025    paris           45         20   sunny
# 9            9  1/2/2025    paris           50         13  cloudy
# 10          10  1/3/2025    paris           54          8  cloudy
# 11          11  1/4/2025    paris           52         10  cloudy

# %%
df.rename(columns={"day":"date"},inplace=True)

# %%
df
# Out:
#     Unnamed: 0      date     city  temperature  windspeed   event
# 0            0  1/1/2025  newyork           32          6   rainy
# 1            1  1/2/2025  newyork           36          7   sunny
# 2            2  1/3/2025  newyork           28         12    snow
# 3            3  1/4/2025  newyork           33          7   sunny
# 4            4  1/1/2025   mumbai           90          5   sunny
# 5            5  1/2/2025   mumbai           85         12     fog
# 6            6  1/3/2025   mumbai           87         15     fog
# 7            7  1/4/2025   mumbai           92          5   rainy
# 8            8  1/1/2025    paris           45         20   sunny
# 9            9  1/2/2025    paris           50         13  cloudy
# 10          10  1/3/2025    paris           54          8  cloudy
# 11          11  1/4/2025    paris           52         10  cloudy

# %%
df.drop(columns=["Unnamed: 0"])#space is mandot
# Out:
#         date     city  temperature  windspeed   event
# 0   1/1/2025  newyork           32          6   rainy
# 1   1/2/2025  newyork           36          7   sunny
# 2   1/3/2025  newyork           28         12    snow
# 3   1/4/2025  newyork           33          7   sunny
# 4   1/1/2025   mumbai           90          5   sunny
# 5   1/2/2025   mumbai           85         12     fog
# 6   1/3/2025   mumbai           87         15     fog
# 7   1/4/2025   mumbai           92          5   rainy
# 8   1/1/2025    paris           45         20   sunny
# 9   1/2/2025    paris           50         13  cloudy
# 10  1/3/2025    paris           54          8  cloudy
# 11  1/4/2025    paris           52         10  cloudy

# %%
data1=df.loc[df["city"]=="mumbai"]

# %%
data1
# Out:
#    Unnamed: 0      date    city  temperature  windspeed  event
# 4           4  1/1/2025  mumbai           90          5  sunny
# 5           5  1/2/2025  mumbai           85         12    fog
# 6           6  1/3/2025  mumbai           87         15    fog
# 7           7  1/4/2025  mumbai           92          5  rainy

# %%
hyderabad_weather={"date":['1/4/2025','2/4/2025','3/4/2025','4/4/2025','5/4/2025'],
                  "city":["nagour","amerpet","srnagar","erragadda","kbnagar"],
                  "temp":[45,35,46,48,50],
                  "winspeed":[5,6,7,8,9],
                  "event":["sunny","rainy","fogg","cloudy","snow"]}

# %%
hyderabad_weather
# Out:
# {'date': ['1/4/2025', '2/4/2025', '3/4/2025', '4/4/2025', '5/4/2025'],
#  'city': ['nagour', 'amerpet', 'srnagar', 'erragadda', 'kbnagar'],
#  'temp': [45, 35, 46, 48, 50],
#  'winspeed': [5, 6, 7, 8, 9],
#  'event': ['sunny', 'rainy', 'fogg', 'cloudy', 'snow']}

# %%
h=pd.DataFrame(hyderabad_weather)

# %%
h
# Out:
#        date       city  temp  winspeed   event
# 0  1/4/2025     nagour    45         5   sunny
# 1  2/4/2025    amerpet    35         6   rainy
# 2  3/4/2025    srnagar    46         7    fogg
# 3  4/4/2025  erragadda    48         8  cloudy
# 4  5/4/2025    kbnagar    50         9    snow

# %%
import pandas as pd

# %%
df=pd.read_csv("matches.csv")

# %%
df
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
#How many matches played in rajkot
df["city"]=="Rajkot"
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1090    False
# 1091    False
# 1092    False
# 1093    False
# 1094    False
# Name: city, Length: 1095, dtype: bool

# %%
df[df["city"]=="Rajkot"]
# Out:
#           id season    city        date match_type player_of_match  \
# 522   980911   2016  Rajkot  2016-04-14     League        AJ Finch
# 531   980929   2016  Rajkot  2016-04-21     League         B Kumar
# 535   980937   2016  Rajkot  2016-04-24     League         V Kohli
# 544   980955   2016  Rajkot  2016-05-01     League        AR Patel
# 547   980961   2016  Rajkot  2016-05-03     League         RR Pant
# 579  1082593   2017  Rajkot  2017-04-07     League         CA Lynn
# 589  1082603   2017  Rajkot  2017-04-14     League          AJ Tye
# 596  1082610   2017  Rajkot  2017-04-18     League        CH Gayle
# 602  1082616   2017  Rajkot  2017-04-23     League         HM Amla
# 610  1082625   2017  Rajkot  2017-04-29     League       KH Pandya
#
#                                       venue          team1  \
# 522  Saurashtra Cricket Association Stadium  Gujarat Lions
# 531  Saurashtra Cricket Association Stadium  Gujarat Lions
# ...

# %%
df[df["city"]=="Rajkot"].shape[0]
# Out:
# 10

# %%
#create the function to get the count of the matches
def count_matches(city):
    return df[df["city"]==city].shape[0]

# %%
count_matches("Hyderabad")
# Out:
# 77

# %%
count_matches("Mumbai")
# Out:
# 173

# %%
#all matches palyed in banglore after 2010
v1=df["city"]=="Bangalore"
v2=df["date"]>'2010-01-01'

# %%
v1
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1090    False
# 1091    False
# 1092    False
# 1093    False
# 1094    False
# Name: city, Length: 1095, dtype: bool

# %%
v2
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1090     True
# 1091     True
# 1092     True
# 1093     True
# 1094     True
# Name: date, Length: 1095, dtype: bool

# %%
df[v1&v2].shape[0]
# Out:
# 58

# %%
df[df["city"]=="Bangalore"]
# Out:
#           id   season       city        date   match_type  player_of_match  \
# 0     335982  2007/08  Bangalore  2008-04-18       League      BB McCullum
# 10    335992  2007/08  Bangalore  2008-04-26       League        SR Watson
# 14    335996  2007/08  Bangalore  2008-04-28       League         MS Dhoni
# 21    336034  2007/08  Bangalore  2008-05-03       League          P Kumar
# 24    336006  2007/08  Bangalore  2008-05-05       League      S Sreesanth
# ..       ...      ...        ...         ...          ...              ...
# 606  1082621     2017  Bangalore  2017-04-27       League           AJ Tye
# 618  1082633     2017  Bangalore  2017-05-05       League   Sandeep Sharma
# 621  1082636     2017  Bangalore  2017-05-07       League        SP Narine
# 633  1082648     2017  Bangalore  2017-05-17   Eliminator  NM Coulter-Nile
# 634  1082649     2017  Bangalore  2017-05-19  Qualifier 2        KV Sharma
#
#                      venue                        team1  \
# ...

# %%
df["winner"]
# Out:
# 0             Kolkata Knight Riders
# 1               Chennai Super Kings
# 2                  Delhi Daredevils
# 3       Royal Challengers Bangalore
# 4             Kolkata Knight Riders
#                    ...
# 1090            Sunrisers Hyderabad
# 1091          Kolkata Knight Riders
# 1092               Rajasthan Royals
# 1093            Sunrisers Hyderabad
# 1094          Kolkata Knight Riders
# Name: winner, Length: 1095, dtype: object

# %%
df["winner"].count()
# Out:
# 1090

# %%
df["winner"].value_counts()
# Out:
# winner
# Mumbai Indians                 144
# Chennai Super Kings            138
# Kolkata Knight Riders          131
# Royal Challengers Bangalore    116
# Rajasthan Royals               112
# Kings XI Punjab                 88
# Sunrisers Hyderabad             88
# Delhi Daredevils                67
# Delhi Capitals                  48
# Deccan Chargers                 29
# Gujarat Titans                  28
# Lucknow Super Giants            24
# Punjab Kings                    24
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Royal Challengers Bengaluru      7
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: count, dtype: int64

# %%
#top five teams whose played maximum matches?
df["team1"].value_counts()
# Out:
# team1
# Royal Challengers Bangalore    135
# Chennai Super Kings            128
# Mumbai Indians                 123
# Kolkata Knight Riders          121
# Rajasthan Royals               101
# Kings XI Punjab                 92
# Sunrisers Hyderabad             86
# Delhi Daredevils                85
# Delhi Capitals                  41
# Deccan Chargers                 39
# Punjab Kings                    31
# Lucknow Super Giants            23
# Pune Warriors                   23
# Gujarat Titans                  21
# Gujarat Lions                   16
# Royal Challengers Bengaluru      9
# Rising Pune Supergiant           7
# Rising Pune Supergiants          7
# Kochi Tuskers Kerala             7
# Name: count, dtype: int64

# %%
df["team2"].value_counts()
# Out:
# team2
# Mumbai Indians                 138
# Kolkata Knight Riders          130
# Rajasthan Royals               120
# Chennai Super Kings            110
# Royal Challengers Bangalore    105
# Kings XI Punjab                 98
# Sunrisers Hyderabad             96
# Delhi Daredevils                76
# Delhi Capitals                  50
# Deccan Chargers                 36
# Punjab Kings                    25
# Gujarat Titans                  24
# Pune Warriors                   23
# Lucknow Super Giants            21
# Gujarat Lions                   14
# Rising Pune Supergiant           9
# Rising Pune Supergiants          7
# Kochi Tuskers Kerala             7
# Royal Challengers Bengaluru      6
# Name: count, dtype: int64

# %%
result=df["team1"].value_counts()+df["team2"].value_counts()

# %%
result
# Out:
# Chennai Super Kings            238
# Deccan Chargers                 75
# Delhi Capitals                  91
# Delhi Daredevils               161
# Gujarat Lions                   30
# Gujarat Titans                  45
# Kings XI Punjab                190
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          251
# Lucknow Super Giants            44
# Mumbai Indians                 261
# Pune Warriors                   46
# Punjab Kings                    56
# Rajasthan Royals               221
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    240
# Royal Challengers Bengaluru     15
# Sunrisers Hyderabad            182
# Name: count, dtype: int64

# %%
result.sort_values(ascending=False).head(2)
# Out:
# Mumbai Indians           261
# Kolkata Knight Riders    251
# Name: count, dtype: int64

# %%
#How can you get the total number of runs scored in the entire dataset?

# %%
df.head(2)
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
#
#                    team2                  toss_winner toss_decision  \
# 0  Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1    Chennai Super Kings          Chennai Super Kings           bat
#
#                   winner result  result_margin  target_runs  target_overs  \
# 0  Kolkata Knight Riders   runs          140.0        223.0          20.0
# 1    Chennai Super Kings   runs           33.0        241.0          20.0
#
#   super_over method    umpire1      umpire2
# 0          N    NaN  Asad Rauf  RE Koertzen
# ...

# %%
df["target_runs"].sum()
# Out:
# 180927.0

# %%
#How can you get the total number of wickets taken in the entire dataset?
df["result"].value_counts()
# Out:
# result
# wickets      578
# runs         498
# tie           14
# no result      5
# Name: count, dtype: int64

# %%
#How can you get the average runs scored per match
df["target_runs"].mean()
# Out:
# 165.68406593406593

# %%
#How can you find the player who has won the most 'Player of the Match' awards?
df["player_of_match"].value_counts()
# Out:
# player_of_match
# AB de Villiers       25
# CH Gayle             22
# RG Sharma            19
# DA Warner            18
# V Kohli              18
#                      ..
# NV Ojha               1
# KV Sharma             1
# Washington Sundar     1
# PD Collingwood        1
# Shahbaz Ahmed         1
# Name: count, Length: 291, dtype: int64

# %%
df["player_of_match"].value_counts().head(1)
# Out:
# player_of_match
# AB de Villiers    25
# Name: count, dtype: int64

# %%
#this is another formula
df["player_of_match"].value_counts().idxmax()
# Out:
# 'AB de Villiers'

# %%
#How can you get the number of matches played in each venue?
df["venue"].value_counts()
# Out:
# venue
# Eden Gardens                                                             77
# Wankhede Stadium                                                         73
# M Chinnaswamy Stadium                                                    65
# Feroz Shah Kotla                                                         60
# Rajiv Gandhi International Stadium, Uppal                                49
# MA Chidambaram Stadium, Chepauk                                          48
# Sawai Mansingh Stadium                                                   47
# Dubai International Cricket Stadium                                      46
# Wankhede Stadium, Mumbai                                                 45
# Punjab Cricket Association Stadium, Mohali                               35
# Sheikh Zayed Stadium                                                     29
# Sharjah Cricket Stadium                                                  28
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv("matches.csv")

# %%
df
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
#highest scored match in whole dataset
df[df['target_runs']==df['target_runs'].max()]
# Out:
#            id season       city        date match_type player_of_match  \
# 1053  1426268   2024  Bengaluru  2024-04-15     League         TM Head
#
#                                  venue                team1  \
# 1053  M Chinnaswamy Stadium, Bengaluru  Sunrisers Hyderabad
#
#                             team2                  toss_winner toss_decision  \
# 1053  Royal Challengers Bengaluru  Royal Challengers Bengaluru         field
#
#                    winner result  result_margin  target_runs  target_overs  \
# 1053  Sunrisers Hyderabad   runs           25.0        288.0          20.0
#
#      super_over method       umpire1   umpire2
# 1053          N    NaN  AK Chaudhary  R Pandit

# %%
#Which teams played the most matches against each other?
df.groupby(["team1","team2"]).size().sort_values(ascending=False).head(1)
# Out:
# team1                team2
# Chennai Super Kings  Mumbai Indians    22
# dtype: int64

# %%
#another sortcut
df[["team1","team2"]].value_counts().head(1)
# Out:
# team1                team2
# Chennai Super Kings  Mumbai Indians    22
# Name: count, dtype: int64

# %%
#Find the number of matches played in each year
df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
g=df["date"]

# %%
g

# %%
g["year"].value_counts()
# Out:
# year
# 2008    58
# 2009    57
# 2010    60
# 2011    73
# 2012    74
# 2013    76
# 2014    60
# 2015    59
# 2016    60
# 2017    59
# 2018    60
# 2019    60
# 2020    60
# 2021    60
# 2022    74
# 2023    74
# 2024    71
# Name: count, dtype: int64

# %%
#creating function for  opinion columns:
def match_opinion(runs):
    if runs>100:
        return 'onesided'
    elif runs>50 and runs<100:
        return 'avarage'
    else:
        return 'tough'

# %%
df["opinion"]=df["result_margin"].apply(match_opinion)

# %%
df.head(3)
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
#
#                    team2                  toss_winner  ... target_runs  \
# 0  Kolkata Knight Riders  Royal Challengers Bangalore  ...       223.0
# 1    Chennai Super Kings          Chennai Super Kings  ...       241.0
# 2       Rajasthan Royals             Rajasthan Royals  ...       130.0
#
#   target_overs super_over  method    umpire1         umpire2 day month  year  \
# ...

# %%
#calculate the winning percentage of each team

# %%
a=df["winner"].value_counts()

# %%
a
# Out:
# winner
# Mumbai Indians                 144
# Chennai Super Kings            138
# Kolkata Knight Riders          131
# Royal Challengers Bangalore    116
# Rajasthan Royals               112
# Kings XI Punjab                 88
# Sunrisers Hyderabad             88
# Delhi Daredevils                67
# Delhi Capitals                  48
# Deccan Chargers                 29
# Gujarat Titans                  28
# Lucknow Super Giants            24
# Punjab Kings                    24
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Royal Challengers Bengaluru      7
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: count, dtype: int64

# %%
result=df["team1"].value_counts() + df["team2"].value_counts()

# %%
result
# Out:
# Chennai Super Kings            238
# Deccan Chargers                 75
# Delhi Capitals                  91
# Delhi Daredevils               161
# Gujarat Lions                   30
# Gujarat Titans                  45
# Kings XI Punjab                190
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          251
# Lucknow Super Giants            44
# Mumbai Indians                 261
# Pune Warriors                   46
# Punjab Kings                    56
# Rajasthan Royals               221
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    240
# Royal Challengers Bengaluru     15
# Sunrisers Hyderabad            182
# Name: count, dtype: int64

# %%
p=(a/result)*100

# %%
p
# Out:
# Chennai Super Kings            57.983193
# Deccan Chargers                38.666667
# Delhi Capitals                 52.747253
# Delhi Daredevils               41.614907
# Gujarat Lions                  43.333333
# Gujarat Titans                 62.222222
# Kings XI Punjab                46.315789
# Kochi Tuskers Kerala           42.857143
# Kolkata Knight Riders          52.191235
# Lucknow Super Giants           54.545455
# Mumbai Indians                 55.172414
# Pune Warriors                  26.086957
# Punjab Kings                   42.857143
# Rajasthan Royals               50.678733
# Rising Pune Supergiant         62.500000
# Rising Pune Supergiants        35.714286
# Royal Challengers Bangalore    48.333333
# Royal Challengers Bengaluru    46.666667
# Sunrisers Hyderabad            48.351648
# Name: count, dtype: float64

# %%
data1={
    "id":[1,2,3,4],
    "name":["sachin","virat","rohit","dhoni"]}

# %%
df1=pd.DataFrame(data1)

# %%
df1
# Out:
#    id    name
# 0   1  sachin
# 1   2   virat
# 2   3   rohit
# 3   4   dhoni

# %%
data2={
    "id":[3,4,5,6],
    "name":["rohit","dhoni","hardeek","jaddu"]
}

# %%
df2=pd.DataFrame(data2)

# %%
df2
# Out:
#    id     name
# 0   3    rohit
# 1   4    dhoni
# 2   5  hardeek
# 3   6    jaddu

# %%
result_inner=pd.merge(df1,df2,on="id",how="inner")

# %%
result_inner
# Out:
#    id name_x name_y
# 0   3  rohit  rohit
# 1   4  dhoni  dhoni

# %%
result_left=pd.merge(df1,df2,on="id",how="left")

# %%
result_left
# Out:
#    id  name_x name_y
# 0   1  sachin    NaN
# 1   2   virat    NaN
# 2   3   rohit  rohit
# 3   4   dhoni  dhoni

# %%
result_right=pd.merge(df1,df2,on="id",how="right")

# %%
result_right
# Out:
#    id name_x   name_y
# 0   3  rohit    rohit
# 1   4  dhoni    dhoni
# 2   5    NaN  hardeek
# 3   6    NaN    jaddu

# %%
result_outer=pd.merge(df1,df2,on="id",how="outer")

# %%
result_outer
# Out:
#    id  name_x   name_y
# 0   1  sachin      NaN
# 1   2   virat      NaN
# 2   3   rohit    rohit
# 3   4   dhoni    dhoni
# 4   5     NaN  hardeek
# 5   6     NaN    jaddu
